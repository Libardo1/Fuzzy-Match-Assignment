# %%
import pandas as pd
from fuzzywuzzy import fuzz
import string

# %%
data = pd.read_excel("Z:/Sid/Sidd/studies/MS/1st Spring/DSO 562/HW/HW 02/NY property 1 million.xlsx")

# %%
data['OWNER']=data['OWNER'].astype(str)

# %%
def get_ratio(row):
    name = row['OWNER']
    return fuzz.token_set_ratio(name, "JOHN SMITH")

answer = data[data.apply(get_ratio, axis=1) > 90]

# %%
print(answer)
# Out:
#           RECORD        BBLE  BLOCK   LOT EASEMENT                 OWNER  \
# 16666      16667  5054391029   5439  1029      NaN            JOHN SMITH
# 17317      17318  3035380125   3538   125      NaN         SMITH, JOHN H
# 39964      39965  3010350040   1035    40      NaN            JOHN SMITH
# 57870      57871  4047050066   4705    66      NaN         SMITH, JOHN L
# 108230    108231  3039840101   3984   101      NaN          JOHN L SMITH
# 124439    124440  4101870050  10187    50      NaN         SMITH, JOHNNY
# 148762    148763  3038270043   3827    43      NaN           SMITH, JOHN
# 192494    192495  4046680019   4668    19      NaN    SMITH, JR., JOHN L
# 195973    195974  2033750051   3375    51      NaN          SMITH JOHN J
# 205498    205499  3073540058   7354    58      NaN          JOHN J SMITH
# 248246    248247  5016090028   1609    28      NaN            JOHN SMITH
# 252237    252238  3017780020   1778    20      NaN          JOHN L SMITH
# ...

# %%
# checking with RegEx to compare answers with fuzzy matching and setting the correct ratio value. 
data[data['OWNER'].str.match((re.compile(".*JOHN.*SMITH.*|.*SMITH.*JOHN.*")))]
# Out:
#           RECORD        BBLE  BLOCK   LOT EASEMENT                 OWNER  \
# 16666      16667  5054391029   5439  1029      NaN            JOHN SMITH
# 17317      17318  3035380125   3538   125      NaN         SMITH, JOHN H
# 39964      39965  3010350040   1035    40      NaN            JOHN SMITH
# 57870      57871  4047050066   4705    66      NaN         SMITH, JOHN L
# 108230    108231  3039840101   3984   101      NaN          JOHN L SMITH
# 124439    124440  4101870050  10187    50      NaN         SMITH, JOHNNY
# 148762    148763  3038270043   3827    43      NaN           SMITH, JOHN
# 192494    192495  4046680019   4668    19      NaN    SMITH, JR., JOHN L
# 195973    195974  2033750051   3375    51      NaN          SMITH JOHN J
# 205498    205499  3073540058   7354    58      NaN          JOHN J SMITH
# 248246    248247  5016090028   1609    28      NaN            JOHN SMITH
# 252237    252238  3017780020   1778    20      NaN          JOHN L SMITH
# ...

# %%
answer.to_excel('output.xlsx')
